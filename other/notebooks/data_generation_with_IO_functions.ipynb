# %% [markdown]
# # Data generation with I/O functions
# "by_input" function generate datas from an instance of the class elements, and works together with IOfunctions methods.

# %%
from model.simple_access.functions import IOfunctions
from model.simple_access.functions import Generator

elements = IOfunctions.get_input("input/all_elements.json")
results = Generator.by_input(elements)
if results : #if you choose "by chunk" generation, 'results' is None 
    IOfunctions.manage_output(elements, results)
# Out:
# Start time: 2020-10-01 03:24:29.670263
# End time: 2020-10-01 03:24:29.690863
# Generating process time: 0:00:00.020600
# Total memory usage of [Y, X]: 1.66 KB
#
# features:
#            0         1         2         3         4
# 0  -2.345760  0.854837 -1.150240  1.266382  6.485481
# 1  -2.829775  1.325398 -3.100002  4.641155  3.031467
# 2  -2.498096  2.964900 -4.540804 -0.935884  2.732105
# 3  -3.331813  3.360916  2.564154  3.378040 -2.606912
# 4  -1.405315 -5.600288 -0.411469 -3.361760 -1.462105
# 5  -0.791010  1.466731 -1.361429  2.196534 -0.573396
# 6   0.190029 -0.183611  1.632137 -0.380871 -1.531016
# 7  -0.822885  2.458012  0.572229  5.306782 -0.762397
# 8  -3.730353 -3.311607 -5.261733  7.820792  1.208507
# 9   0.644463  7.829955  0.759278 -1.586161  2.260447
# 10  0.707933  2.696519 -2.214461 -0.387551 -0.323701
# 11  0.099669  4.204360 -0.740678  1.368438  1.255761
# 12  0.239912 -3.466742  0.243675  4.455945 -2.279911
# ...
